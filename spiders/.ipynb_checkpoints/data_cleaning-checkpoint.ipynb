# %%
import pandas as pd
data=pd.read_excel("dataset_books.xlsx")
data
# Out:
#                                                   title  \
# 0     Becoming a Data Head: How to Think, Speak and ...
# 1     Ace the Data Science Interview: 201 Real Inter...
# 2     Fundamentals of Data Engineering: Plan and Bui...
# 3     Essential Math for Data Science: Take Control ...
# 4     Data Science for Business: What You Need to Kn...
# ...                                                 ...
# 1782  Regression Analysis: An Intuitive Guide for Us...
# 1783                            Statistics, 4th Edition
# 1784         Elementary Statistics: Picturing the World
# 1785  Making Sense of Statistics: A Conceptual Overview
# 1786                  Psychology Statistics For Dummies
#
#                                                  author   price      pages  \
# 0     ['by ', 'Alex J. Gutman', ' and ', 'Jordan Gol...   24.49  272 pages
# 1           ['by ', 'Nick Singh', ' and ', 'Kevin Huo']   26.00  301 pages
# ...

# %%
len(data['ISBN_13'].unique())
# Out:
# 958

# %%
data_unique=data.drop_duplicates('ISBN_13')
data_unique
# Out:
#                                                   title  \
# 0     Becoming a Data Head: How to Think, Speak and ...
# 1     Ace the Data Science Interview: 201 Real Inter...
# 2     Fundamentals of Data Engineering: Plan and Bui...
# 3     Essential Math for Data Science: Take Control ...
# 4     Data Science for Business: What You Need to Kn...
# ...                                                 ...
# 1776  The Book of R: A First Course in Programming a...
# 1781  Basic Business Statistics: A Casebook (Textboo...
# 1784         Elementary Statistics: Picturing the World
# 1785  Making Sense of Statistics: A Conceptual Overview
# 1786                  Psychology Statistics For Dummies
#
#                                                  author   price      pages  \
# 0     ['by ', 'Alex J. Gutman', ' and ', 'Jordan Gol...   24.49  272 pages
# 1           ['by ', 'Nick Singh', ' and ', 'Kevin Huo']   26.00  301 pages
# ...

# %%
import numpy as np
def author(x):
    authors=''
    for elem in np.array(x):
        authors=authors+elem
    print(authors)
    print(elem)
    return authors
data_unique['author'].apply(author)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-94411056f2f0> in <module>
#       7     print(elem)
#       8     return authors
# ----> 9 data_unique['author'].apply(author)
#      10
#
# ~\anaconda3\envs\env1_cloned_tf\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4431         dtype: float64
#    4432         """
# -> 4433         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4434
#    4435     def _reduce(
#
# ~\anaconda3\envs\env1_cloned_tf\lib\site-packages\pandas\core\apply.py in apply(self)
#    1086             return self.apply_str()
#    1087
# -> 1088         return self.apply_standard()
#    1089
#    1090     def agg(self):
#
# ~\anaconda3\envs\env1_cloned_tf\lib\site-packages\pandas\core\apply.py in apply_standard(self)
# ...

# %%
data_unique['author'].dtype
# Out:
# dtype('O')

# %%
''+'3'
# Out:
# '3'

# %%
x=['1','s','z']
a=''
for elem in x:
    a=a+elem
print(a)
# Out:
# 1sz
